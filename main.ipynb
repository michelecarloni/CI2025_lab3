# %% [markdown]
# ### CITY SHORTEST PATH

# %%
from itertools import product, combinations
import numpy as np
import networkx as nx
from icecream import ic
from algorithms import *

# %%
def create_problem(
    size: int,
    *,
    density: float = 1.0,
    negative_values: bool = False,
    noise_level: float = 0.0,
    seed: int = 42,
) -> np.ndarray:
    """Problem generator for Lab3"""
    rng = np.random.default_rng(seed)
    map = rng.random(size=(size, 2))
    problem = rng.random((size, size))
    if negative_values:
        problem = problem * 2 - 1
    problem *= noise_level
    for a, b in product(range(size), repeat=2):
        if rng.random() < density:
            problem[a, b] += np.sqrt(
                np.square(map[a, 0] - map[b, 0]) + np.square(map[a, 1] - map[b, 1])
            )
        else:
            problem[a, b] = np.inf
    np.fill_diagonal(problem, 0)

    return (problem * 1_000).round(), map

# %%
# Create the problem instance
problem, map_data = create_problem(10, density=0.15, noise_level=10, negative_values=True)
masked = np.ma.masked_array(problem, mask=np.isinf(problem))
G = nx.from_numpy_array(masked, create_using=nx.DiGraph)

SIZE = problem.shape[0]

# %%
def get_path_cost(problem_matrix: np.ndarray, path: list) -> float:
    """Calculates the total weight of a path using the problem matrix."""
    if path is None:
        return np.inf
    cost = 0
    for i in range(len(path) - 1):
        u = path[i]
        v = path[i+1]
        cost += problem_matrix[u, v]
    return cost

# %%
for s, d in combinations(range(SIZE), 2):
    path = bfs_path(G, s, d)
    cost = get_path_cost(problem, path)
    
    ic(s, d, path, cost)
# Out:
# ic| s: 0, d: 1, path: None, cost: inf
# ic| s: 0, d: 2, path: [0, 2], cost: np.float64(10280.0)
# ic| s: 0, d: 3, path: [0, 4, 3], cost: np.float64(12230.0)
# ic| s: 0, d: 4, path: [0, 4], cost: np.float64(6214.0)
# ic| s: 0, d: 5, path: None, cost: inf
# ic| s: 0, d: 6, path: [0, 8, 6], cost: np.float64(-6729.0)
# ic| s: 0, d: 7, path: [0, 7], cost: np.float64(-8731.0)
# ic| s: 0, d: 8, path: [0, 8], cost: np.float64(-6480.0)
# ic| s: 0, d: 9, path: [0, 2, 9], cost: np.float64(3885.0)
# ic| s: 1, d: 2, path: [1, 9, 7, 2], cost: np.float64(8165.0)
# ic| s: 1, d: 3, path: None, cost: inf
# ic| s: 1, d: 4, path: None, cost: inf
# ic| s: 1, d: 5, path: [1, 5], cost: np.float64(-5672.0)
# ic| s: 1, d: 6, path: [1, 9, 6], cost: np.float64(8905.0)
# ic| s: 1, d: 7, path: [1, 9, 7], cost: np.float64(8416.0)
# ic| s: 1, d: 8, path: None, cost: inf
# ic| s: 1, d: 9, path: [1, 9], cost: np.float64(3469.0)
# ic| s: 2, d: 3, path: None, cost: inf
# ic| s: 2, d: 4, path: None, cost: inf
# ic| s: 2, d: 5, path: None, cost: inf
# ic| s: 2, d: 6, path: [2, 9, 6], cost: np.float64(-959.0)
# ic| s: 2, d: 7, path: [2, 9, 7], cost: np.float64(-1448.0)
# ic| s: 2, d: 8, path: None, cost: inf
# ic| s: 2, d: 9, path: [2, 9], cost: np.float64(-6395.0)
# ic| s: 3, d: 4, path: [3, 4], cost: np.float64(4820.0)
# ic| s: 3, d: 5, path: None, cost: inf
# ic| s: 3, d: 6, path: [3, 2, 9, 6], cost: np.float64(5473.0)
# ic| s: 3, d: 7, path: [3, 2, 9, 7], cost: np.float64(4984.0)
# ic| s: 3, d: 8, path: [3, 4, 0, 8], cost: np.float64(2354.0)
# ic| s: 3, d: 9, path: [3, 2, 9], cost: np.float64(37.0)
# ic| s: 4, d: 5, path: None, cost: inf
# ic| s: 4, d: 6, path: [4, 0, 8, 6], cost: np.float64(-2715.0)
# ic| s: 4, d: 7, path: [4, 0, 7], cost: np.float64(-4717.0)
# ic| s: 4, d: 8, path: [4, 0, 8], cost: np.float64(-2466.0)
# ic| s: 4, d: 9, path: [4, 0, 2, 9], cost: np.float64(7899.0)
# ic| s: 5, d: 6, path: None, cost: inf
# ic| s: 5, d: 7, path: None, cost: inf
# ic| s: 5, d: 8, path: None, cost: inf
# ic| s: 5, d: 9, path: None, cost: inf
# ic| s: 6, d: 7, path: [6, 7], cost: np.float64(-134.0)
# ic| s: 6, d: 8, path: None, cost: inf
# ic| s: 6, d: 9, path: [6, 7, 2, 9], cost: np.float64(-6780.0)
# ic| s: 7, d: 8, path: None, cost: inf
# ic| s: 7, d: 9, path: [7, 2, 9], cost: np.float64(-6646.0)
# ic| s: 8, d: 9, path: [8, 3, 2, 9], cost: np.float64(10172.0)

# %%
print("--- Depth-First Search (DFS) Results ---")
for s, d in combinations(range(SIZE), 2):
    path = dfs_path(G, s, d)
    cost = get_path_cost(problem, path)
    
    ic(s, d, path, cost)
# Out:
# --- Depth-First Search (DFS) Results ---
# ic| s: 0, d: 1, path: None, cost: inf
# ic| s: 0, d: 2, path: [0, 2], cost: np.float64(10280.0)
# ic| s: 0, d: 3, path: [0, 4, 3], cost: np.float64(12230.0)
# ic| s: 0, d: 4, path: [0, 4], cost: np.float64(6214.0)
# ic| s: 0, d: 5, path: None, cost: inf
# ic| s: 0, d: 6, path: [0, 2, 9, 6], cost: np.float64(9321.0)
# ic| s: 0, d: 7, path: [0, 2, 9, 6, 7], cost: np.float64(9187.0)
# ic| s: 0, d: 8, path: [0, 8], cost: np.float64(-6480.0)
# ic| s: 0, d: 9, path: [0, 2, 9], cost: np.float64(3885.0)
# ic| s: 1, d: 2, path: [1, 9, 6, 7, 2], cost: np.float64(8520.0)
# ic| s: 1, d: 3, path: None, cost: inf
# ic| s: 1, d: 4, path: None, cost: inf
# ic| s: 1, d: 5, path: [1, 5], cost: np.float64(-5672.0)
# ic| s: 1, d: 6, path: [1, 9, 6], cost: np.float64(8905.0)
# ic| s: 1, d: 7, path: [1, 9, 6, 7], cost: np.float64(8771.0)
# ic| s: 1, d: 8, path: None, cost: inf
# ic| s: 1, d: 9, path: [1, 9], cost: np.float64(3469.0)
# ic| s: 2, d: 3, path: None, cost: inf
# ic| s: 2, d: 4, path: None, cost: inf
# ic| s: 2, d: 5, path: None, cost: inf
# ic| s: 2, d: 6, path: [2, 9, 6], cost: np.float64(-959.0)
# ic| s: 2, d: 7, path: [2, 9, 6, 7], cost: np.float64(-1093.0)
# ic| s: 2, d: 8, path: None, cost: inf
# ic| s: 2, d: 9, path: [2, 9], cost: np.float64(-6395.0)
# ic| s: 3, d: 4, path: [3, 4], cost: np.float64(4820.0)
# ic| s: 3, d: 5, path: None, cost: inf
# ic| s: 3, d: 6, path: [3, 2, 9, 6], cost: np.float64(5473.0)
# ic| s: 3, d: 7, path: [3, 2, 9, 6, 7], cost: np.float64(5339.0)
# ic| s: 3, d: 8, path: [3, 4, 0, 8], cost: np.float64(2354.0)
# ic| s: 3, d: 9, path: [3, 2, 9], cost: np.float64(37.0)
# ic| s: 4, d: 5, path: None, cost: inf
# ic| s: 4, d: 6, path: [4, 0, 2, 9, 6], cost: np.float64(13335.0)
# ic| s: 4, d: 7, path: [4, 0, 2, 9, 6, 7], cost: np.float64(13201.0)
# ic| s: 4, d: 8, path: [4, 0, 8], cost: np.float64(-2466.0)
# ic| s: 4, d: 9, path: [4, 0, 2, 9], cost: np.float64(7899.0)
# ic| s: 5, d: 6, path: None, cost: inf
# ic| s: 5, d: 7, path: None, cost: inf
# ic| s: 5, d: 8, path: None, cost: inf
# ic| s: 5, d: 9, path: None, cost: inf
# ic| s: 6, d: 7, path: [6, 7], cost: np.float64(-134.0)
# ic| s: 6, d: 8, path: None, cost: inf
# ic| s: 6, d: 9, path: [6, 7, 2, 9], cost: np.float64(-6780.0)
# ic| s: 7, d: 8, path: None, cost: inf
# ic| s: 7, d: 9, path: [7, 2, 9], cost: np.float64(-6646.0)
# ic| s: 8, d: 9, path: [8, 3, 2, 9], cost: np.float64(10172.0)

# %%
for s, d in combinations(range(SIZE), 2):
    path, cost = dijkstra_path(G, s, d)
    ic(s, d, path, cost)
# Out:
# ic| s: 0, d: 1, path: None, cost: inf
# ic| s: 0, d: 2, path: [0, 7, 2], cost: -8982.0
# ic| s: 0, d: 3, path: [0, 8, 3], cost: 3655.0
# ic| s: 0, d: 4, path: [0, 8, 4], cost: -329.0
# ic| s: 0, d: 5, path: None, cost: inf
# ic| s: 0, d: 6, path: [0, 7, 2, 9, 6], cost: -9941.0
# ic| s: 0, d: 7, path: [0, 7], cost: -8731.0
# ic| s: 0, d: 8, path: [0, 8], cost: -6480.0
# ic| s: 0, d: 9, path: [0, 7, 2, 9], cost: -15377.0
# ic| s: 1, d: 2, path: [1, 9, 7, 2], cost: 8165.0
# ic| s: 1, d: 3, path: None, cost: inf
# ic| s: 1, d: 4, path: None, cost: inf
# ic| s: 1, d: 5, path: [1, 5], cost: -5672.0
# ic| s: 1, d: 6, path: [1, 9, 6], cost: 8905.0
# ic| s: 1, d: 7, path: [1, 9, 7], cost: 8416.0
# ic| s: 1, d: 8, path: None, cost: inf
# ic| s: 1, d: 9, path: [1, 9], cost: 3469.0
# ic| s: 2, d: 3, path: None, cost: inf
# ic| s: 2, d: 4, path: None, cost: inf
# ic| s: 2, d: 5, path: None, cost: inf
# ic| s: 2, d: 6, path: [2, 9, 6], cost: -959.0
# ic| s: 2, d: 7, path: [2, 9, 7], cost: -1448.0
# ic| s: 2, d: 8, path: None, cost: inf
# ic| s: 2, d: 9, path: [2, 9], cost: -6395.0
# ic| s: 3, d: 4, path: [3, 4], cost: 4820.0
# ic| s: 3, d: 5, path: None, cost: inf
# ic| s: 3, d: 6, path: [3, 2, 9, 6], cost: 5473.0
# ic| s: 3, d: 7, path: [3, 2, 9, 7], cost: 4984.0
# ic| s: 3, d: 8, path: [3, 4, 0, 8], cost: 2354.0
# ic| s: 3, d: 9, path: [3, 2, 9], cost: 37.0
# ic| s: 4, d: 5, path: None, cost: inf
# ic| s: 4, d: 6, path: [4, 0, 7, 2, 9, 6], cost: -5927.0
# ic| s: 4, d: 7, path: [4, 0, 7], cost: -4717.0
# ic| s: 4, d: 8, path: [4, 0, 8], cost: -2466.0
# ic| s: 4, d: 9, path: [4, 0, 7, 2, 9], cost: -11363.0
# ic| s: 5, d: 6, path: None, cost: inf
# ic| s: 5, d: 7, path: None, cost: inf
# ic| s: 5, d: 8, path: None, cost: inf
# ic| s: 5, d: 9, path: None, cost: inf
# ic| s: 6, d: 7, path: [6, 7], cost: -134.0
# ic| s: 6, d: 8, path: None, cost: inf
# ic| s: 6, d: 9, path: [6, 7, 2, 9], cost: -6780.0
# ic| s: 7, d: 8, path: None, cost: inf
# ic| s: 7, d: 9, path: [7, 2, 9], cost: -6646.0
# ic| s: 8, d: 9, path: [8, 6, 7, 2, 9], cost: -7029.0

# %%
print("--- A* Search (Correct: Positive-Weight Graph) ---")
for s, d in combinations(range(SIZE), 2):
    path, cost = a_star_path(G, s, d, map_data)
    ic(s, d, path, cost)
# Out:
# --- A* Search (Correct: Positive-Weight Graph) ---
# ic| s: 0, d: 1, path: None, cost: inf
# ic| s: 0, d: 2, path: [0, 7, 2], cost: -8982.0
# ic| s: 0, d: 3, path: [0, 8, 3], cost: 3655.0
# ic| s: 0, d: 4, path: [0, 8, 4], cost: -329.0
# ic| s: 0, d: 5, path: None, cost: inf
# ic| s: 0, d: 6, path: [0, 7, 2, 9, 6], cost: -9941.0
# ic| s: 0, d: 7, path: [0, 7], cost: -8731.0
# ic| s: 0, d: 8, path: [0, 8], cost: -6480.0
# ic| s: 0, d: 9, path: [0, 7, 2, 9], cost: -15377.0
# ic| s: 1, d: 2, path: [1, 9, 7, 2], cost: 8165.0
# ic| s: 1, d: 3, path: None, cost: inf
# ic| s: 1, d: 4, path: None, cost: inf
# ic| s: 1, d: 5, path: [1, 5], cost: -5672.0
# ic| s: 1, d: 6, path: [1, 9, 6], cost: 8905.0
# ic| s: 1, d: 7, path: [1, 9, 7], cost: 8416.0
# ic| s: 1, d: 8, path: None, cost: inf
# ic| s: 1, d: 9, path: [1, 9], cost: 3469.0
# ic| s: 2, d: 3, path: None, cost: inf
# ic| s: 2, d: 4, path: None, cost: inf
# ic| s: 2, d: 5, path: None, cost: inf
# ic| s: 2, d: 6, path: [2, 9, 6], cost: -959.0
# ic| s: 2, d: 7, path: [2, 9, 7], cost: -1448.0
# ic| s: 2, d: 8, path: None, cost: inf
# ic| s: 2, d: 9, path: [2, 9], cost: -6395.0
# ic| s: 3, d: 4, path: [3, 4], cost: 4820.0
# ic| s: 3, d: 5, path: None, cost: inf
# ic| s: 3, d: 6, path: [3, 2, 9, 6], cost: 5473.0
# ic| s: 3, d: 7, path: [3, 2, 9, 7], cost: 4984.0
# ic| s: 3, d: 8, path: [3, 4, 0, 8], cost: 2354.0
# ic| s: 3, d: 9, path: [3, 2, 9], cost: 37.0
# ic| s: 4, d: 5, path: None, cost: inf
# ic| s: 4, d: 6, path: [4, 0, 7, 2, 9, 6], cost: -5927.0
# ic| s: 4, d: 7, path: [4, 0, 7], cost: -4717.0
# ic| s: 4, d: 8, path: [4, 0, 8], cost: -2466.0
# ic| s: 4, d: 9, path: [4, 0, 7, 2, 9], cost: -11363.0
# ic| s: 5, d: 6, path: None, cost: inf
# ic| s: 5, d: 7, path: None, cost: inf
# ic| s: 5, d: 8, path: None, cost: inf
# ic| s: 5, d: 9, path: None, cost: inf
# ic| s: 6, d: 7, path: [6, 7], cost: -134.0
# ic| s: 6, d: 8, path: None, cost: inf
# ic| s: 6, d: 9, path: [6, 7, 2, 9], cost: -6780.0
# ic| s: 7, d: 8, path: None, cost: inf
# ic| s: 7, d: 9, path: [7, 2, 9], cost: -6646.0
# ic| s: 8, d: 9, path: [8, 6, 7, 2, 9], cost: -7029.0
